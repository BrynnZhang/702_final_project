# %%
import pandas as pd

life_exp = pd.read_csv("UNLifeExp.csv")

# %%
print(life_exp)
# Out:
#                          Country or Area  Year(s) Variant    Value
# 0      ADB region: Central and West Asia     2101  Medium      NaN
# 1      ADB region: Central and West Asia     2100  Medium  79.1328
# 2      ADB region: Central and West Asia     2099  Medium  79.0004
# 3      ADB region: Central and West Asia     2098  Medium  78.8630
# 4      ADB region: Central and West Asia     2097  Medium  78.7253
# ...                                  ...      ...     ...      ...
# 84355                           Zimbabwe     1954  Medium  51.0240
# 84356                           Zimbabwe     1953  Medium  50.6334
# 84357                           Zimbabwe     1952  Medium  50.2394
# 84358                           Zimbabwe     1951  Medium  49.8355
# 84359                           Zimbabwe     1950  Medium  49.4155
#
# [84360 rows x 4 columns]

# %%
life_exp = life_exp.drop("Variant", axis=1)
print(life_exp)
# Out:
#                          Country or Area  Year(s)    Value
# 0      ADB region: Central and West Asia     2101      NaN
# 1      ADB region: Central and West Asia     2100  79.1328
# 2      ADB region: Central and West Asia     2099  79.0004
# 3      ADB region: Central and West Asia     2098  78.8630
# 4      ADB region: Central and West Asia     2097  78.7253
# ...                                  ...      ...      ...
# 84355                           Zimbabwe     1954  51.0240
# 84356                           Zimbabwe     1953  50.6334
# 84357                           Zimbabwe     1952  50.2394
# 84358                           Zimbabwe     1951  49.8355
# 84359                           Zimbabwe     1950  49.4155
#
# [84360 rows x 3 columns]

# %%
life_exp = life_exp.dropna()
print(life_exp)
# Out:
#                          Country or Area  Year(s)    Value
# 1      ADB region: Central and West Asia     2100  79.1328
# 2      ADB region: Central and West Asia     2099  79.0004
# 3      ADB region: Central and West Asia     2098  78.8630
# 4      ADB region: Central and West Asia     2097  78.7253
# 5      ADB region: Central and West Asia     2096  78.5855
# ...                                  ...      ...      ...
# 84355                           Zimbabwe     1954  51.0240
# 84356                           Zimbabwe     1953  50.6334
# 84357                           Zimbabwe     1952  50.2394
# 84358                           Zimbabwe     1951  49.8355
# 84359                           Zimbabwe     1950  49.4155
#
# [83805 rows x 3 columns]

# %%
print(life_exp["Country or Area"].unique())
# Out:
# ['ADB region: Central and West Asia' 'ADB region: Developed'
#  'ADB region: East Asia' 'ADB region: South Asia'
#  'ADB region: Southeast Asia' 'ADB region: The Pacific' 'Afghanistan'
#  'Africa' 'African Group' 'African Union' 'African Union: Central Africa'
#  'African Union: Eastern Africa' 'African Union: Northern Africa'
#  'African Union: Southern Africa' 'African Union: Western Africa'
#  'African, Caribbean and Pacific (ACP) Group of States' 'Albania'
#  'Algeria' 'American Samoa' 'Americas' 'Andean Community' 'Andorra'
#  'Angola' 'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba'
#  'Asia' 'Asia-Pacific Economic Cooperation (APEC)' 'Asia-Pacific Group'
#  'Association of Southeast Asian Nations (ASEAN)' 'AUKUS' 'Australia'
#  'Australia/New Zealand' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain'
#  'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize'
#  'Belt-Road Initiative (BRI)' 'Belt-Road Initiative: Africa'
# ...

# %%
life_exp = life_exp[life_exp["Country or Area"] != "Africa"]
life_exp = life_exp[life_exp["Country or Area"] != "Western Africa"]
life_exp = life_exp[life_exp["Country or Area"] != "Eastern Africa"]
life_exp = life_exp[life_exp["Country or Area"] != "Northern Africa"]
life_exp = life_exp[life_exp["Country or Area"] != "Middle Africa"]
life_exp = life_exp[life_exp["Country or Area"] != "Southern Africa"]
life_exp = life_exp[life_exp["Country or Area"] != "Sub-Saharan Africa"]
life_exp = life_exp[life_exp["Country or Area"] != "Americas"]
life_exp = life_exp[life_exp["Country or Area"] != "North America"]
life_exp = life_exp[life_exp["Country or Area"] != "Northern America"]
life_exp = life_exp[life_exp["Country or Area"] != "South America"]
life_exp = life_exp[life_exp["Country or Area"] != "World"]
life_exp = life_exp[life_exp["Country or Area"] != "ECE: CIS (CWG)"]
life_exp = life_exp[life_exp["Country or Area"] != "ECE: West Balkans (ST7)"]
life_exp = life_exp[life_exp["Country or Area"] != "Australia/New Zealand"]
life_exp = life_exp[life_exp["Country or Area"] != "Guadeloupe"]
life_exp = life_exp[life_exp["Country or Area"] != "Martinique"]
life_exp = life_exp[life_exp["Country or Area"] != "Mayotte"]
life_exp = life_exp[life_exp["Country or Area"] != "Melanesia"]
life_exp = life_exp[life_exp["Country or Area"] != "Micronesia"]
life_exp = life_exp[life_exp["Country or Area"] != "Non-Self-Governing Territories"]
life_exp = life_exp[life_exp["Country or Area"] != "Greenland"]
life_exp = life_exp[life_exp["Country or Area"] != "Western Sahara"]
life_exp = life_exp[life_exp["Country or Area"] != "Falkland Islands"]
life_exp = life_exp[life_exp["Country or Area"] != "China, Hong Kong SAR"]
life_exp = life_exp[life_exp["Country or Area"] != "China, Macao SAR"]
life_exp = life_exp[life_exp["Country or Area"] != "Isle of Man"]
life_exp = life_exp[life_exp["Country or Area"] != "Guam"]
life_exp = life_exp[life_exp["Country or Area"] != "Bonaire, Sint Eustatius and Saba"]
life_exp = life_exp[life_exp["Country or Area"] != "Polynesia"]
life_exp = life_exp[life_exp["Country or Area"] != "Saint Helena"]
life_exp = life_exp[life_exp["Country or Area"] != "Turks and Caicos Islands"]

# %%
keywords = [
    "region",
    "area",
    "Belt-Road",
    "initiative",
    "WHO",
    "UNFPA",
    "organization",
    "group",
    "latin",
    "IPCC",
    "alliance",
    "europe",
    "asia",
    "association",
    "access",
    "union",
    "cooperation",
    "community",
    "BRIC",
    "CANZUK",
    "eca",
    "escap",
    "escwa",
    "eclac",
    "fvey",
    "commonwealth",
    "income",
    "IPEF",
    "AUKUS",
    "Oceania",
    "countries",
    "league",
    "developed",
    "developing",
    "dependencies",
    "LLDC",
    "agreement",
    "organisation",
    "member states",
    "dialogue",
    "ais",
    "Southern Common Market",
    "french",
    "SIDS",
]

remove_keywords = "|".join(keywords)

life_exp = life_exp[
    ~life_exp["Country or Area"].str.contains(remove_keywords, case=False)
]

# %%
life_exp["Country or Area"] = life_exp["Country or Area"].replace("CuraÃ§ao", "Curaçao")
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "CÃ´te d'Ivoire", "Côte d'Ivoire"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Kosovo (under UNSC res. 1244)", "Kosovo"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Bolivia (Plurinational State of)", "Bolivia"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Venezuela (Bolivarian Republic of)", "Venezuela"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Iran (Islamic Republic of)", "Iran"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Falkland Islands (Malvinas)", "Falkland Islands"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Micronesia (Fed. States of)", "Micronesia"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Saint Martin (French part)", "Saint Martin"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Sint Maarten (Dutch part)", "Sint Maarten"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Russian Federation", "Russia"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace(
    "Saint BarthÃ©lemy", "Saint Barthélemy"
)
life_exp["Country or Area"] = life_exp["Country or Area"].replace("TÃ¼rkiye", "Turkey")

# %%
print(life_exp["Country or Area"].unique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'British Virgin Islands' 'Brunei Darussalam' 'Bulgaria' 'Burkina Faso'
#  'Burundi' "Côte d'Ivoire" 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada'
#  'Caribbean' 'Cayman Islands' 'Central African Republic' 'Central America'
#  'Chad' 'Chile' 'China' 'Colombia' 'Comoros' 'Congo' 'Cook Islands'
#  'Costa Rica' 'Croatia' 'Cuba' 'Curaçao' 'Cyprus' 'Czechia'
#  "Dem. People's Republic of Korea" 'Democratic Republic of the Congo'
#  'Denmark' 'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Falkland Islands' 'Faroe Islands' 'Fiji' 'Finland' 'France'
# ...

# %%
print(life_exp)
# Out:
#       Country or Area  Year(s)    Value
# 913       Afghanistan     2100  77.3068
# 914       Afghanistan     2099  77.1936
# 915       Afghanistan     2098  77.0671
# 916       Afghanistan     2097  76.9444
# 917       Afghanistan     2096  76.8053
# ...               ...      ...      ...
# 84355        Zimbabwe     1954  51.0240
# 84356        Zimbabwe     1953  50.6334
# 84357        Zimbabwe     1952  50.2394
# 84358        Zimbabwe     1951  49.8355
# 84359        Zimbabwe     1950  49.4155
#
# [33522 rows x 3 columns]

# %%
life_exp.to_csv("clean_life_exp.csv", index=False)
