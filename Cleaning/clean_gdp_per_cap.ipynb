# %%
import pandas as pd

gdp_per_cap = pd.read_csv("UNGDP.csv")

# %%
print(gdp_per_cap)
# Out:
#      Country or Area                                               Year  \
# 0        Afghanistan                                               2023
# 1        Afghanistan                                               2022
# 2        Afghanistan                                               2021
# 3        Afghanistan                                               2020
# 4        Afghanistan                                               2019
# ...              ...                                                ...
# 8263        Zimbabwe                                               1992
# 8264        Zimbabwe                                               1991
# 8265        Zimbabwe                                               1990
# 8266   footnoteSeqID                                           Footnote
# 8267               2  Based on official data. Official data is not a...
#
#             Value  Value Footnotes
# 0     2211.280635              NaN
# ...

# %%
gdp_per_cap = gdp_per_cap.drop("Value Footnotes", axis=1)
print(gdp_per_cap)
# Out:
#      Country or Area                                               Year  \
# 0        Afghanistan                                               2023
# 1        Afghanistan                                               2022
# 2        Afghanistan                                               2021
# 3        Afghanistan                                               2020
# 4        Afghanistan                                               2019
# ...              ...                                                ...
# 8263        Zimbabwe                                               1992
# 8264        Zimbabwe                                               1991
# 8265        Zimbabwe                                               1990
# 8266   footnoteSeqID                                           Footnote
# 8267               2  Based on official data. Official data is not a...
#
#             Value
# 0     2211.280635
# 1     2122.995815
# 2     2144.166570
# 3     2561.981761
# ...

# %%
gdp_per_cap = gdp_per_cap.dropna()
print(gdp_per_cap)
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2023  2211.280635
# 1        Afghanistan  2022  2122.995815
# 2        Afghanistan  2021  2144.166570
# 3        Afghanistan  2020  2561.981761
# 4        Afghanistan  2019  2583.485332
# ...              ...   ...          ...
# 8261        Zimbabwe  1994  1955.678953
# 8262        Zimbabwe  1993  1754.985282
# 8263        Zimbabwe  1992  1721.491174
# 8264        Zimbabwe  1991  1902.877431
# 8265        Zimbabwe  1990  1790.178448
#
# [8266 rows x 3 columns]

# %%
print(gdp_per_cap["Country or Area"].unique())
# Out:
# ['Afghanistan' 'Africa Eastern and Southern' 'Africa Western and Central'
#  'Albania' 'Algeria' 'Andorra' 'Angola' 'Antigua and Barbuda' 'Arab World'
#  'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria' 'Azerbaijan'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin'
#  'Bermuda' 'Bhutan' 'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'Brunei' 'Bulgaria' 'Burkina Faso' 'Burundi' "CÃ´te d'Ivoire"
#  'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada' 'Caribbean small states'
#  'Cayman Islands' 'Central African Republic'
#  'Central Europe and the Baltics' 'Chad' 'Chile' 'China' 'Colombia'
#  'Comoros' 'Congo' 'Costa Rica' 'Croatia' 'CuraÃ§ao' 'Cyprus' 'Czechia'
#  'Dem. Rep. Congo' 'Denmark' 'Djibouti' 'Dominica' 'Dominican Republic'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD)' 'Ecuador' 'Egypt' 'El Salvador'
# ...

# %%
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "The Bahamas", "Bahamas"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Brunei", "Brunei Darussalam"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "CuraÃ§ao", "Curaçao"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "CÃ´te d'Ivoire", "Côte d'Ivoire"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Congo", "Democratic Republic of the Congo"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "The Gambia", "Gambia"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Kyrgyz Republic", "Kyrgyzstan"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Lao PDR", "Lao People's Democratic Republic"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Moldova", "Republic of Moldova"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Russia", "Russian Federation"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "St. Kitts and Nevis", "Saint Kitts and Nevis"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "St. Lucia", "Saint Lucia"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "St. Vincent and the Grenadines", "Saint Vincent and the Grenadines"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Venezuela (Bolivarian Republic of)", "Venezuela"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "SÃ£o TomÃ© and Principe", "Sao Tome and Principe"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Slovak Republic", "Slovakia"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "TÃ¼rkiye", "Türkiye"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Korea", "Republic of Korea"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "United States", "United States of America"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "United Kingdom", "United Kingdom of Great Britain and Northern Ireland"
)
gdp_per_cap["Country or Area"] = gdp_per_cap["Country or Area"].replace(
    "Tanzania", "United Republic of Tanzania"
)

# %%
print(gdp_per_cap["Country or Area"].unique())
# Out:
# ['Afghanistan' 'Africa Eastern and Southern' 'Africa Western and Central'
#  'Albania' 'Algeria' 'Andorra' 'Angola' 'Antigua and Barbuda' 'Arab World'
#  'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria' 'Azerbaijan'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin'
#  'Bermuda' 'Bhutan' 'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' "Côte d'Ivoire"
#  'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada' 'Caribbean small states'
#  'Cayman Islands' 'Central African Republic'
#  'Central Europe and the Baltics' 'Chad' 'Chile' 'China' 'Colombia'
#  'Comoros' 'Democratic Republic of the Congo' 'Costa Rica' 'Croatia'
#  'Curaçao' 'Cyprus' 'Czechia' 'Dem. Rep. Congo' 'Denmark' 'Djibouti'
#  'Dominica' 'Dominican Republic' 'Early-demographic dividend'
#  'East Asia & Pacific' 'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD)' 'Ecuador' 'Egypt' 'El Salvador'
# ...

# %%
countries = pd.read_excel("un_countries.xlsx")
countries = countries["English short"]
countries = countries[:-7]
countries = countries.str.replace(r"\(.*?\)", "", regex=True).str.strip()

# %%
missing = countries[~countries.isin(gdp_per_cap["Country or Area"])]
print(missing)
# Out:
# 38                                     Congo
# 42                                      Cuba
# 45     Democratic People's Republic of Korea
# 98                             Liechtenstein
# 112                                   Monaco
# Name: English short, dtype: object

# %%
gdp_per_cap = gdp_per_cap[gdp_per_cap["Country or Area"].isin(countries)]

# %%
print(len(gdp_per_cap["Country or Area"].unique()))
# Out:
# 188

# %%
print(gdp_per_cap.describe())
# Out:
#                Value
# count    6245.000000
# mean    15628.305624
# std     19518.788576
# min       254.388475
# 25%      2916.532823
# 50%      8112.448245
# 75%     20490.126953
# max    180939.425775

# %%
gdp_per_cap.to_csv("clean_gdp_per_cap.csv", index=False)
